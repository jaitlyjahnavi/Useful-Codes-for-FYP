# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
#EPX 3. top opensouce companies

# %%
df = pd.read_csv('Docker.csv')
df.head()
# Out:
#         Weeks  Adds  Subs  Year        Date
# 0  1546732800  4089 -3282  2019  2019-01-06
# 1  1547337600  2266 -1833  2019  2019-01-13
# 2  1547942400   370  -331  2019  2019-01-20
# 3  1548547200  1429  -758  2019  2019-01-27
# 4  1549152000  1815 -1463  2019  2019-02-03

# %%
import matplotlib.pyplot as plt
from matplotlib import dates as mpl_dates
import datetime
from datetime import datetime,timedelta
#from sklearn.linear_model import LinearRegression
import seaborn as sns
sns.set()

# %%
sum_of_cols=df.sum(axis=0)
print(sum_of_cols)
# Out:
# Weeks                                         269983584000
# Adds                                               1520310
# Subs                                              -1426773
# Year                                                341406
# Date     2019-01-062019-01-132019-01-202019-01-272019-0...
# dtype: object

# %%
name_and_year = df.groupby(['Weeks','Year'])
sum_counts = name_and_year['Adds'].sum().reset_index().sort_values('Adds', ascending=False)
sum_counts.head(25)
# Out:
#           Weeks  Year    Adds
# 13   1554595200  2019  171382
# 59   1582416000  2020  145731
# 165  1646524800  2022  144692
# 154  1639872000  2021  120930
# 117  1617494400  2021   82639
# 65   1586044800  2020   78226
# 166  1647129600  2022   62817
# 86   1598745600  2020   49201
# 5    1549756800  2019   46562
# 24   1561248000  2019   41318
# 47   1575158400  2019   41069
# 9    1552176000  2019   27090
# 33   1566691200  2019   24993
# 56   1580601600  2020   24372
# 61   1583625600  2020   22848
# 52   1578182400  2020   21771
# 97   1605398400  2020   20212
# 69   1588464000  2020   19618
# 96   1604793600  2020   18292
# 15   1555804800  2019   18228
# 48   1575763200  2019   18116
# 38   1569715200  2019   15801
# 75   1592092800  2020   13884
# 162  1644710400  2022   13539
# 151  1638057600  2021   12790

# %%
pr_by_year_docker = df.groupby(['Adds'])['Year'].sum().reset_index().sort_values('Adds', ascending=False)
pr_by_year_docker.head(10)
# Out:
#        Adds  Year
# 162  171382  2019
# 161  145731  2020
# 160  144692  2022
# 159  120930  2021
# 158   82639  2021
# 157   78226  2020
# 156   62817  2022
# 155   49201  2020
# 154   46562  2019
# 153   41318  2019

# %%
plot_annual_pr = sns.barplot(data=pr_by_year_docker.query('Year < 2022 & Year > 2018'),x='Year',y='Adds',ci=None)
plot_annual_pr.set_ylabel('Adds For Docker (10000)')
plot_annual_pr.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
df['Date']=pd.to_datetime(df['Date'])
print(df)
print()
print(df.dtypes)
# Out:
#           Weeks    Adds   Subs  Year       Date
# 0    1546732800    4089  -3282  2019 2019-01-06
# 1    1547337600    2266  -1833  2019 2019-01-13
# 2    1547942400     370   -331  2019 2019-01-20
# 3    1548547200    1429   -758  2019 2019-01-27
# 4    1549152000    1815  -1463  2019 2019-02-03
# ..          ...     ...    ...   ...        ...
# 164  1645920000    2754  -1716  2022 2022-02-27
# 165  1646524800  144692 -65419  2022 2022-03-06
# 166  1647129600   62817 -14485  2022 2022-03-13
# 167  1647734400    4620  -1150  2022 2022-03-20
# 168  1648339200       4     -4  2022 2022-03-27
#
# [169 rows x 5 columns]
#
# Weeks             int64
# Adds              int64
# Subs              int64
# Year              int64
# Date     datetime64[ns]
# dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'],format='%Y-%m-%d %I-%p')

# %%
commit_date= df['Date']
Adds_repo= df['Adds']

# %%
plt.style.use('seaborn')
plt.plot_date(commit_date,Adds_repo,linestyle='solid')
plt.gcf().autofmt_xdate()
plt.title('Docker')
plt.xlabel('Dates')
plt.ylabel('No.of Additions')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
df = pd.read_csv('Mongodb.csv')
df.head()
# Out:
#         Weeks     Adds     Subs  Year        Date
# 0  1546732800  1131466   -23440  2019  2019-01-06
# 1  1547337600   277604  -379292  2019  2019-01-13
# 2  1547942400    68509   -58581  2019  2019-01-20
# 3  1548547200  1039340 -1038644  2019  2019-01-27
# 4  1549152000    15542   -11800  2019  2019-02-03

# %%
sum_of_cols=df.sum(axis=0)
print(sum_of_cols)
# Out:
# Weeks                                         269983584000
# Adds                                              22926581
# Subs                                             -15791886
# Year                                                341406
# Date     2019-01-062019-01-132019-01-202019-01-272019-0...
# dtype: object

# %%
name_and_year = df.groupby(['Weeks','Year'])
sum_counts = name_and_year['Adds'].sum().reset_index().sort_values('Adds', ascending=False)
sum_counts.head(25)
# Out:
#           Weeks  Year     Adds
# 164  1645920000  2022  6281243
# 122  1620518400  2021  3297790
# 120  1619308800  2021  1740779
# 121  1619913600  2021  1380747
# 0    1546732800  2019  1131466
# 3    1548547200  2019  1039340
# 151  1638057600  2021  1031488
# 19   1558224000  2019   928450
# 21   1559433600  2019   413574
# 1    1547337600  2019   277604
# 26   1562457600  2019   208742
# 28   1563667200  2019   202175
# 83   1596931200  2020   198756
# 9    1552176000  2019   196973
# 70   1589068800  2020   187137
# 159  1642896000  2022   173987
# 39   1570320000  2019   173264
# 15   1555804800  2019   162758
# 119  1618704000  2021   150087
# 32   1566086400  2019   142402
# 27   1563062400  2019   140815
# 12   1553990400  2019   139537
# 129  1624752000  2021   118088
# 118  1618099200  2021   114459
# 75   1592092800  2020   112004

# %%
pr_by_year_mongodb = df.groupby(['Adds'])['Year'].sum().reset_index().sort_values('Adds', ascending=False)
pr_by_year_mongodb.head(10)
# Out:
#         Adds  Year
# 167  6281243  2022
# 166  3297790  2021
# 165  1740779  2021
# 164  1380747  2021
# 163  1131466  2019
# 162  1039340  2019
# 161  1031488  2021
# 160   928450  2019
# 159   413574  2019
# 158   277604  2019

# %%
plot_annual_pr = sns.barplot(data=pr_by_year_mongodb.query('Year < 2022 & Year > 2018'),x='Year',y='Adds',ci=None)
plot_annual_pr.set_ylabel('Adds For Mongodb (10000)')
plot_annual_pr.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
df['Date']=pd.to_datetime(df['Date'])
print(df)
print()
print(df.dtypes)
# Out:
#           Weeks     Adds     Subs  Year       Date
# 0    1546732800  1131466   -23440  2019 2019-01-06
# 1    1547337600   277604  -379292  2019 2019-01-13
# 2    1547942400    68509   -58581  2019 2019-01-20
# 3    1548547200  1039340 -1038644  2019 2019-01-27
# 4    1549152000    15542   -11800  2019 2019-02-03
# ..          ...      ...      ...   ...        ...
# 164  1645920000  6281243  -750546  2022 2022-02-27
# 165  1646524800    41781   -17806  2022 2022-03-06
# 166  1647129600    25021   -11377  2022 2022-03-13
# 167  1647734400    37521   -15303  2022 2022-03-20
# 168  1648339200     5553   -15424  2022 2022-03-27
#
# [169 rows x 5 columns]
#
# Weeks             int64
# Adds              int64
# Subs              int64
# Year              int64
# Date     datetime64[ns]
# dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'],format='%Y-%m-%d %I-%p')

# %%
commit_date= df['Date']
Adds_repo= df['Adds']

# %%
plt.style.use('seaborn')
plt.plot_date(commit_date,Adds_repo,linestyle='solid')
plt.gcf().autofmt_xdate()
plt.title('Mongodb')
plt.xlabel('Dates')
plt.ylabel('No.of Additions')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout(*, pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %%
df = pd.read_csv('result.csv')
df.head()
# Out:
#         Weeks  Adds  Subs  Year        Date
# 0  1546732800     5    -8  2019  2019-01-06
# 1  1547337600    25    -2  2019  2019-01-13
# 2  1547942400     2    -6  2019  2019-01-20
# 3  1548547200    17    -7  2019  2019-01-27
# 4  1549152000     8   -10  2019  2019-02-03

# %%
sum_of_cols=df.sum(axis=0)
print(sum_of_cols)
# Out:
# Weeks                                         273282076800
# Adds                                                948953
# Subs                                               -557071
# Year                                                345450
# Date     2019-01-062019-01-132019-01-202019-01-272019-0...
# dtype: object

# %%
name_and_year = df.groupby(['Weeks','Year'])
sum_counts = name_and_year['Adds'].sum().reset_index().sort_values('Adds', ascending=False)
sum_counts.head(25)
# Out:
#           Weeks  Year    Adds
# 36   1568505600  2019  127416
# 127  1623542400  2021  104567
# 147  1635638400  2021   88820
# 125  1622332800  2021   87594
# 157  1641686400  2022   76093
# 111  1613865600  2021   61838
# 153  1639267200  2021   59836
# 159  1642896000  2022   41517
# 144  1633824000  2021   28957
# 93   1602979200  2020   20242
# 126  1622937600  2021   14069
# 19   1558224000  2019   13424
# 90   1601164800  2020   13235
# 138  1630195200  2021   12340
# 145  1634428800  2021   12059
# 149  1636848000  2021   10002
# 75   1592092800  2020    9924
# 140  1631404800  2021    8341
# 152  1638662400  2021    7990
# 39   1570320000  2019    7780
# 148  1636243200  2021    6895
# 141  1632009600  2021    6230
# 17   1557014400  2019    5592
# 92   1602374400  2020    4745
# 55   1579996800  2020    4346

# %%
pr_by_year_adobe = df.groupby(['Adds'])['Year'].sum().reset_index().sort_values('Adds', ascending=False)
pr_by_year_adobe.head(10)
# Out:
#        Adds  Year
# 121  127416  2019
# 120  104567  2021
# 119   88820  2021
# 118   87594  2021
# 117   76093  2022
# 116   61838  2021
# 115   59836  2021
# 114   41517  2022
# 113   28957  2021
# 112   20242  2020

# %%
plot_annual_pr = sns.barplot(data=pr_by_year_adobe.query('Year < 2022 & Year > 2018'),x='Year',y='Adds',ci=None)
plot_annual_pr.set_ylabel('Adds For Adobe (10000)')
plot_annual_pr.set_xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')
